# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from scipy import stats

# %%
df = pd.read_csv("Placement_data_full_class.csv")

# %%
df
# Out:
#      sl_no gender  ssc_p    ssc_b  hsc_p    hsc_b     hsc_s  degree_p  \
# 0        1      M  67.00   Others  91.00   Others  Commerce     58.00
# 1        2      M  79.33  Central  78.33   Others   Science     77.48
# 2        3      M  65.00  Central  68.00  Central      Arts     64.00
# 3        4      M  56.00  Central  52.00  Central   Science     52.00
# 4        5      M  85.80  Central  73.60  Central  Commerce     73.30
# ..     ...    ...    ...      ...    ...      ...       ...       ...
# 210    211      M  80.60   Others  82.00   Others  Commerce     77.60
# 211    212      M  58.00   Others  60.00   Others   Science     72.00
# 212    213      M  67.00   Others  67.00   Others  Commerce     73.00
# 213    214      F  74.00   Others  66.00   Others  Commerce     58.00
# 214    215      M  62.00  Central  58.00   Others   Science     53.00
#
#       degree_t workex  etest_p specialisation  mba_p      status    salary
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 215 entries, 0 to 214
# Data columns (total 15 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   sl_no           215 non-null    int64
#  1   gender          215 non-null    object
#  2   ssc_p           215 non-null    float64
#  3   ssc_b           215 non-null    object
#  4   hsc_p           215 non-null    float64
#  5   hsc_b           215 non-null    object
#  6   hsc_s           215 non-null    object
#  7   degree_p        215 non-null    float64
#  8   degree_t        215 non-null    object
#  9   workex          215 non-null    object
#  10  etest_p         215 non-null    float64
#  11  specialisation  215 non-null    object
#  12  mba_p           215 non-null    float64
#  13  status          215 non-null    object
#  14  salary          148 non-null    float64
# dtypes: float64(6), int64(1), object(8)
# memory usage: 18.5+ KB

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 215 entries, 0 to 214
# Data columns (total 15 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   sl_no           215 non-null    int64
#  1   gender          215 non-null    object
#  2   ssc_p           215 non-null    float64
#  3   ssc_b           215 non-null    object
#  4   hsc_p           215 non-null    float64
#  5   hsc_b           215 non-null    object
#  6   hsc_s           215 non-null    object
#  7   degree_p        215 non-null    float64
#  8   degree_t        215 non-null    object
#  9   workex          215 non-null    object
#  10  etest_p         215 non-null    float64
#  11  specialisation  215 non-null    object
#  12  mba_p           215 non-null    float64
#  13  status          215 non-null    object
#  14  salary          148 non-null    float64
# dtypes: float64(6), int64(1), object(8)
# memory usage: 18.5+ KB

# %%
df.describe
# Out:
# <bound method NDFrame.describe of      sl_no gender  ssc_p    ssc_b  hsc_p    hsc_b     hsc_s  degree_p  \
# 0        1      M  67.00   Others  91.00   Others  Commerce     58.00
# 1        2      M  79.33  Central  78.33   Others   Science     77.48
# 2        3      M  65.00  Central  68.00  Central      Arts     64.00
# 3        4      M  56.00  Central  52.00  Central   Science     52.00
# 4        5      M  85.80  Central  73.60  Central  Commerce     73.30
# ..     ...    ...    ...      ...    ...      ...       ...       ...
# 210    211      M  80.60   Others  82.00   Others  Commerce     77.60
# 211    212      M  58.00   Others  60.00   Others   Science     72.00
# 212    213      M  67.00   Others  67.00   Others  Commerce     73.00
# 213    214      F  74.00   Others  66.00   Others  Commerce     58.00
# 214    215      M  62.00  Central  58.00   Others   Science     53.00
#
#       degree_t workex  etest_p specialisation  mba_p      status    salary
# ...

# %%
df.isnull().sum()
# Out:
# sl_no              0
# gender             0
# ssc_p              0
# ssc_b              0
# hsc_p              0
# hsc_b              0
# hsc_s              0
# degree_p           0
# degree_t           0
# workex             0
# etest_p            0
# specialisation     0
# mba_p              0
# status             0
# salary            67
# dtype: int64

# %%
df['salary'] = df['salary'].fillna(df['salary'].mean())

# %%
df.head()
# Out:
#    sl_no gender  ssc_p    ssc_b  hsc_p    hsc_b     hsc_s  degree_p  \
# 0      1      M  67.00   Others  91.00   Others  Commerce     58.00
# 1      2      M  79.33  Central  78.33   Others   Science     77.48
# 2      3      M  65.00  Central  68.00  Central      Arts     64.00
# 3      4      M  56.00  Central  52.00  Central   Science     52.00
# 4      5      M  85.80  Central  73.60  Central  Commerce     73.30
#
#     degree_t workex  etest_p specialisation  mba_p      status         salary
# 0   Sci&Tech     No     55.0         Mkt&HR  58.80      Placed  270000.000000
# 1   Sci&Tech    Yes     86.5        Mkt&Fin  66.28      Placed  200000.000000
# 2  Comm&Mgmt     No     75.0        Mkt&Fin  57.80      Placed  250000.000000
# 3   Sci&Tech     No     66.0         Mkt&HR  59.43  Not Placed  288655.405405
# 4  Comm&Mgmt     No     96.8        Mkt&Fin  55.50      Placed  425000.000000

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
df['gender'] = le.fit_transform(df['gender'])

# %%
df['status'] = le.fit_transform(df['status'])

# %%
df['workex'] = le.fit_transform(df['workex'])

# %%
df['specialisation'] = le.fit_transform(df['specialisation'])
df.head()
# Out:
#    sl_no  gender  ssc_p    ssc_b  hsc_p    hsc_b     hsc_s  degree_p  \
# 0      1       1  67.00   Others  91.00   Others  Commerce     58.00
# 1      2       1  79.33  Central  78.33   Others   Science     77.48
# 2      3       1  65.00  Central  68.00  Central      Arts     64.00
# 3      4       1  56.00  Central  52.00  Central   Science     52.00
# 4      5       1  85.80  Central  73.60  Central  Commerce     73.30
#
#     degree_t  workex  etest_p  specialisation  mba_p  status         salary
# 0   Sci&Tech       0     55.0               1  58.80       1  270000.000000
# 1   Sci&Tech       1     86.5               0  66.28       1  200000.000000
# 2  Comm&Mgmt       0     75.0               0  57.80       1  250000.000000
# 3   Sci&Tech       0     66.0               1  59.43       0  288655.405405
# 4  Comm&Mgmt       0     96.8               0  55.50       1  425000.000000

# %%
df.boxplot(column=['ssc_p','hsc_p','degree_p','mba_p'])
plt.title("Boxplot of Academic Scores")
plt.show()

# %%
z = np.abs(stats.zscore(df['mba_p']))
df[z > 3]
# Out:
# Empty DataFrame
# Columns: [sl_no, gender, ssc_p, ssc_b, hsc_p, hsc_b, hsc_s, degree_p, degree_t, workex, etest_p, specialisation, mba_p, status, salary]
# Index: []

# %%
Q1 = df['hsc_p'].quantile(0.25)
Q3 = df['hsc_p'].quantile(0.75)
IQR = Q3 - Q1
lower = Q1 - 1.5 * IQR
upper = Q3 + 1.5 * IQR
print("Lower Bound:", lower)
print("Upper Bound:", upper)
# Out:
# Lower Bound: 42.75
# Upper Bound: 91.15

# %%
df[(df['hsc_p'] < lower) | (df['hsc_p'] > upper)]
# Out:
#      sl_no  gender  ssc_p    ssc_b  hsc_p    hsc_b     hsc_s  degree_p  \
# 24      25       1  76.50   Others  97.70   Others   Science     78.86
# 42      43       1  49.00   Others  39.00  Central   Science     65.00
# 49      50       0  50.00   Others  37.00   Others      Arts     52.00
# 120    121       1  58.00   Others  40.00   Others   Science     59.00
# 134    135       0  77.44  Central  92.00   Others  Commerce     72.00
# 169    170       1  59.96   Others  42.16   Others   Science     61.26
# 177    178       0  73.00  Central  97.00   Others  Commerce     79.00
# 206    207       1  41.00  Central  42.00  Central   Science     60.00
#
#       degree_t  workex  etest_p  specialisation  mba_p  status         salary
# 24    Sci&Tech       0    97.40               0  74.01       1  360000.000000
# 42      Others       0    63.00               0  51.21       0  288655.405405
# 49      Others       0    65.00               1  56.11       0  288655.405405
# ...

# %%
median = df['hsc_p'].median()
df['hsc_p'] = np.where((df['hsc_p'] < lower) | (df['hsc_p'] > upper),median,df['hsc_p'])

# %%
df['salary'].hist()
plt.title("Salary Before Log")
plt.xlabel("Salary")
plt.ylabel("Frequency")
plt.show()
df['salary'].skew()
# Out:
# np.float64(4.288798850070048)

# %%
np.float64(4.288798850070048)
# Out:
# np.float64(4.288798850070048)

# %%
df['log_salary'] = np.log10(df['salary'])
df['log_salary'].hist()
plt.title("Salary After Log")
plt.xlabel("Log Salary")
plt.ylabel("Frequency")
plt.show()
df['log_salary'].skew()
# Out:
# np.float64(1.9500125921488516)

# %%
np.float64(1.9500125921488516)
# Out:
# np.float64(1.9500125921488516)

# %%
plt.scatter(df['mba_p'], df['salary'])
plt.xlabel("MBA Percentage")
plt.ylabel("Salary")
plt.title("MBA vs Salary")
plt.show()
