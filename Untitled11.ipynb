# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_csv("annex1.csv")

# %%
df
# Out:
#            Item Code                                     Item Name  \
# 0    102900005115168                              Niushou Shengcai
# 1    102900005115199                             Sichuan Red Cedar
# 2    102900005115625                         Local Xiaomao Cabbage
# 3    102900005115748                                  White Caitai
# 4    102900005115762                                      Amaranth
# ..               ...                                           ...
# 246  106958851400125                    Haixian Mushroom (Bag) (4)
# 247  106971533450003                      Haixian Mushroom (Bunch)
# 248  106971533455008                    Haixian Mushroom (Bag) (3)
# 249  106973223300667  Chinese Caterpillar Fungus Flowers (Box) (2)
# 250  106973990980123                 Hfyg Haixian Mushroom (Bunch)
#
#      Category Code           Category Name
# 0       1011010101  Flower/Leaf Vegetables
# 1       1011010101  Flower/Leaf Vegetables
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 251 entries, 0 to 250
# Data columns (total 4 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Item Code      251 non-null    int64
#  1   Item Name      251 non-null    object
#  2   Category Code  251 non-null    int64
#  3   Category Name  251 non-null    object
# dtypes: int64(2), object(2)
# memory usage: 6.0+ KB

# %%
df.isnull().sum().sum()
# Out:
# np.int64(0)

# %%
df.describe()
# Out:
#           Item Code  Category Code
# count  2.510000e+02   2.510000e+02
# mean   1.031908e+14   1.011010e+09
# std    1.048400e+12   2.915469e+02
# min    1.029000e+14   1.011010e+09
# 25%    1.029000e+14   1.011010e+09
# 50%    1.029000e+14   1.011011e+09
# 75%    1.029000e+14   1.011011e+09
# max    1.069740e+14   1.011011e+09

# %%
df.columns
# Out:
# Index(['Item Code', 'Item Name', 'Category Code', 'Category Name'], dtype='object')

# %%
df.dtypes
# Out:
# Item Code         int64
# Item Name        object
# Category Code     int64
# Category Name    object
# dtype: object

# %%
df["Category Code"].mean()
# Out:
# np.float64(1011010414.7609562)

# %%
df.mode()
# Out:
#            Item Code                                 Item Name  Category Code  \
# 0    102900005115168                Apricot Bao Mushroom (Bag)   1.011010e+09
# 1    102900005115199                                  Broccoli            NaN
# 2    102900005115250                           Chinese Cabbage            NaN
# 3    102900005115625  Chinese Caterpillar Fungus Flowers (Bag)            NaN
# 4    102900005115748                                       NaN            NaN
# ..               ...                                       ...            ...
# 246  106971533455008                                       NaN            NaN
# 247  106971563780002                                       NaN            NaN
# 248  106972776821582                                       NaN            NaN
# 249  106973223300667                                       NaN            NaN
# 250  106973990980123                                       NaN            NaN
#
#               Category Name
# ...

# %%
df['Category Name'].mode()
# Out:
# 0    Flower/Leaf Vegetables
# Name: Category Name, dtype: object

# %%
df.min()
# Out:
# Item Code                    102900005115168
# Item Name                7 Colour Pepper (1)
# Category Code                     1011010101
# Category Name    Aquatic Tuberous Vegetables
# dtype: object

# %%
df.max()
# Out:
# Item Code        106973990980123
# Item Name         Zhuyecai (Bag)
# Category Code         1011010801
# Category Name            Solanum
# dtype: object
