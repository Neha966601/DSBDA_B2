# %%
import pandas as pd

# %%
df = pd.DataFrame(
    {
        "A": [4,5,6],
        "B": [7,8,9],
        "C": [10,11,12]
    },
    index=[1,2,3]
)

df = pd.DataFrame(
[[4, 7, 10],
[5, 8, 11],
[6, 9, 12]],
index=[1, 2, 3],
columns=['a', 'b', 'c'])

# %%
df = pd.DataFrame( {
    "Name": ["Neha", "Gauri", "Sakshi"],
    "Age": [25,30,35],
    "Location": ["Nagar", "Nashik", "Pune"]
    
},
    index=[1,2,3]
)

# %%
df
# Out:
#      Name  Age Location
# 1    Neha   25    Nagar
# 2   Gauri   30   Nashik
# 3  Sakshi   35     Pune

# %%
df.head()
# Out:
#      Name  Age Location
# 1    Neha   25    Nagar
# 2   Gauri   30   Nashik
# 3  Sakshi   35     Pune

# %%
df.tail()
# Out:
#      Name  Age Location
# 1    Neha   25    Nagar
# 2   Gauri   30   Nashik
# 3  Sakshi   35     Pune

# %%
df.shape
# Out:
# (3, 3)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 3 entries, 1 to 3
# Data columns (total 3 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Name      3 non-null      object
#  1   Age       3 non-null      int64
#  2   Location  3 non-null      object
# dtypes: int64(1), object(2)
# memory usage: 72.0+ bytes

# %%
df.describe()
# Out:
#         Age
# count   3.0
# mean   30.0
# std     5.0
# min    25.0
# 25%    27.5
# 50%    30.0
# 75%    32.5
# max    35.0

# %%
df['Age'].max()
# Out:
# np.int64(35)

# %%
df['Age'].min()
# Out:
# np.int64(25)

# %%
df['Age'].mean()
# Out:
# np.float64(30.0)

# %%
df.drop_duplicates()
# Out:
#      Name  Age Location
# 1    Neha   25    Nagar
# 2   Gauri   30   Nashik
# 3  Sakshi   35     Pune

# %%
df = pd.DataFrame( {
    "Name": ["Neha", "Gauri", "Sakshi", "Gita"],
    "Age": [25,30,35,25],
    "Location": ["Nagar", "Nashik", "Pune", "Seattle"]
    
},
    index=[1,2,3,4]
  )

# %%
df
# Out:
#      Name  Age Location
# 1    Neha   25    Nagar
# 2   Gauri   30   Nashik
# 3  Sakshi   35     Pune
# 4    Gita   25  Seattle

# %%
df.drop_duplicates()
# Out:
#      Name  Age Location
# 1    Neha   25    Nagar
# 2   Gauri   30   Nashik
# 3  Sakshi   35     Pune
# 4    Gita   25  Seattle

# %%
df.loc[1]
# Out:
# Name         Neha
# Age            25
# Location    Nagar
# Name: 1, dtype: object

# %%
df.iloc[0:]
# Out:
#      Name  Age Location
# 1    Neha   25    Nagar
# 2   Gauri   30   Nashik
# 3  Sakshi   35     Pune
# 4    Gita   25  Seattle

# %%
df.drop(4)
# Out:
#      Name  Age Location
# 1    Neha   25    Nagar
# 2   Gauri   30   Nashik
# 3  Sakshi   35     Pune

# %%
df.drop(4)
# Out:
#      Name  Age Location
# 1    Neha   25    Nagar
# 2   Gauri   30   Nashik
# 3  Sakshi   35     Pune

# %%
df[df.Age < 30]
# Out:
#    Name  Age Location
# 1  Neha   25    Nagar
# 4  Gita   25  Seattle

# %%
df.isnull()
# Out:
#     Name    Age  Location
# 1  False  False     False
# 2  False  False     False
# 3  False  False     False
# 4  False  False     False
